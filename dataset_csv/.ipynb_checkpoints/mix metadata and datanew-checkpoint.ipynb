# %%
import os
import pandas as pd

# %%
data_file1 = pd.read_csv('metadata.csv')
data_file2 = pd.read_csv('data_new.csv')

# %%
data_file1
# Out:
#     patientid  offset sex   age                   finding RT_PCR_positive  \
# 0           2     0.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 1           2     3.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 2           2     5.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 3           2     6.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 4           4     0.0   F  52.0  Pneumonia/Viral/COVID-19               Y
# ..        ...     ...  ..   ...                       ...             ...
# 945       479     0.0   F  40.0                 Pneumonia             NaN
# 946       479    70.0   F  40.0                 Pneumonia             NaN
# 947       480     NaN   M  26.0                 Pneumonia             NaN
# 948       481     NaN   M  50.0                 Pneumonia             NaN
# 949       481     NaN   M  50.0                 Pneumonia             NaN
#
#     survival intubated intubation_present went_icu  ...              date  \
# ...

# %%
data_file2
# Out:
#                                filename                   finding  \
# 0     2020.02.26.20027938-p6-80_3%1.png  Pneumonia/Viral/COVID-19
# 1      2020.03.04.20031047-p13-84%5.png  Pneumonia/Viral/COVID-19
# 2       2020.02.24.20027052-p8-73%3.png  Pneumonia/Viral/COVID-19
# 3    2020.03.01.20029769-p21-73_2%1.png  Pneumonia/Viral/COVID-19
# 4        2020.03.12.20027185-p8-218.png  Pneumonia/Viral/COVID-19
# ..                                  ...                       ...
# 494                              46.jpg                No Finding
# 495                            2145.png                No Finding
# 496                              68.jpg                No Finding
# 497                            1307.png                No Finding
# 498                            1211.png                No Finding
#
#                                         clinical_notes
# 0    ['Fig. 3 Clinical photographs of the positive ...
# 1    ['FIGURE 2, Different imaging features for hea...
# ...

# %%
data_mix = pd.concat([data_file1, data_file2], ignore_index=True)

# %%
data_mix
# Out:
#      patientid  offset  sex   age                   finding RT_PCR_positive  \
# 0            2     0.0    M  65.0  Pneumonia/Viral/COVID-19               Y
# 1            2     3.0    M  65.0  Pneumonia/Viral/COVID-19               Y
# 2            2     5.0    M  65.0  Pneumonia/Viral/COVID-19               Y
# 3            2     6.0    M  65.0  Pneumonia/Viral/COVID-19               Y
# 4            4     0.0    F  52.0  Pneumonia/Viral/COVID-19               Y
# ...        ...     ...  ...   ...                       ...             ...
# 1444       NaN     NaN  NaN   NaN                No Finding             NaN
# 1445       NaN     NaN  NaN   NaN                No Finding             NaN
# 1446       NaN     NaN  NaN   NaN                No Finding             NaN
# 1447       NaN     NaN  NaN   NaN                No Finding             NaN
# 1448       NaN     NaN  NaN   NaN                No Finding             NaN
#
# ...

# %%
data_mix.to_csv('data_mix_full.csv', index=False)
